# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Define the impurity measure and parameters for tree construction
criterion = 'gini'
max_depth = 3

# Define the number of times to split the data into train and test sets
num_splits = 5

# Create empty lists to store the training and test accuracies
train_accs = []
test_accs = []

# Split the data into train and test sets multiple times and train a decision tree model on each split
for i in range(num_splits):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=i)

    # Train a decision tree model on the training data
    model = DecisionTreeClassifier(criterion=criterion, max_depth=max_depth)
    model.fit(X_train, y_train)

    # Evaluate the accuracy of the model on the training data
    y_train_pred = model.predict(X_train)
    train_acc = accuracy_score(y_train, y_train_pred)
    train_accs.append(train_acc)

    # Evaluate the accuracy of the model on the test data
    y_test_pred = model.predict(X_test)
    test_acc = accuracy_score(y_test, y_test_pred)
    test_accs.append(test_acc)

# Print the average training and test accuracies
print("Average training accuracy:", sum(train_accs) / len(train_accs))
print("Average test accuracy:", sum(test_accs) / len(test_accs))
# Out:
# Average training accuracy: 0.975
# Average test accuracy: 0.9666666666666666

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Define the impurity measures and parameters for tree construction
criteria = ['gini', 'entropy']
max_depths = [3, 5, 7]

# Define the number of times to split the data into train and test sets
num_splits = 5

# Train a decision tree model for each combination of impurity measure and maximum depth
for criterion in criteria:
    for max_depth in max_depths:
        # Create empty lists to store the training and test accuracies for this tree
        train_accs, test_accs = [], []

        # Split the data into train and test sets multiple times and train a decision tree model on each split
        for i in range(num_splits):
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=i)
            model = DecisionTreeClassifier(criterion=criterion, max_depth=max_depth)
            model.fit(X_train, y_train)

            # Evaluate the accuracy of the model on the training data
            y_train_pred = model.predict(X_train)
            train_acc = accuracy_score(y_train, y_train_pred)
            train_accs.append(train_acc)

            # Evaluate the accuracy of the model on the test data
            y_test_pred = model.predict(X_test)
            test_acc = accuracy_score(y_test, y_test_pred)
            test_accs.append(test_acc)

        # Print the average training and test accuracies for this tree
        print(f"Decision tree with criterion='{criterion}', max_depth={max_depth}:")
        print(f"\tAverage training accuracy: {sum(train_accs)/len(train_accs):.3f}")
        print(f"\tAverage test accuracy: {sum(test_accs)/len(test_accs):.3f}")

        # Plot the tree structure
        plt.figure()
        plot_tree(model, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
        plt.show()
# Out:
# Decision tree with criterion='gini', max_depth=3:
# 	Average training accuracy: 0.975
# 	Average test accuracy: 0.967
# Decision tree with criterion='gini', max_depth=5:
# 	Average training accuracy: 1.000
# 	Average test accuracy: 0.973
# Decision tree with criterion='gini', max_depth=7:
# 	Average training accuracy: 1.000
# 	Average test accuracy: 0.973
# Decision tree with criterion='entropy', max_depth=3:
# 	Average training accuracy: 0.975
# 	Average test accuracy: 0.967
# Decision tree with criterion='entropy', max_depth=5:
# 	Average training accuracy: 0.998
# 	Average test accuracy: 0.960
# Decision tree with criterion='entropy', max_depth=7:
# 	Average training accuracy: 1.000
# 	Average test accuracy: 0.973

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Define the impurity measures and parameters for tree construction
criteria = ['gini', 'entropy']
max_depths = [3, 5, 7]

# Define the number of times to split the data into train and test sets
num_splits = 5

# Define the selected trees to observe
selected_trees = [('gini', 3), ('entropy', 5)]

# Train and evaluate the selected decision trees
for criterion, max_depth in selected_trees:
    # Split the data into train and test sets multiple times and train a decision tree model on each split
    for i in range(num_splits):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=i)
        model = DecisionTreeClassifier(criterion=criterion, max_depth=max_depth)
        model.fit(X_train, y_train)

        # Evaluate the accuracy of the model on the test data
        y_test_pred = model.predict(X_test)
        test_acc = model.score(X_test, y_test)

        # Print the classification performance and confusion matrix for this tree and split
        print(f"Decision tree with criterion='{criterion}', max_depth={max_depth}, split {i+1}:")
        print(f"\tTest accuracy: {test_acc:.3f}")
        print(f"\tConfusion matrix:\n{confusion_matrix(y_test, y_test_pred)}")

        # Plot the tree structure
        plt.figure()
        plot_tree(model, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
        plt.show()

        # Determine which pair(s) of classes are likely to be confused with each other
        for true_class in range(3):
            for pred_class in range(3):
                if true_class != pred_class:
                    n_confused = confusion_matrix(y_test, y_test_pred)[true_class, pred_class]
                    if n_confused > 0:
                        print(f"\tClass {iris.target_names[true_class]} confused with class {iris.target_names[pred_class]}: {n_confused} times")
# Out:
# Decision tree with criterion='gini', max_depth=3, split 1:
# 	Test accuracy: 0.967
# 	Confusion matrix:
# [[11  0  0]
#  [ 0 13  0]
#  [ 0  1  5]]
# 	Class virginica confused with class versicolor: 1 times
# Decision tree with criterion='gini', max_depth=3, split 2:
# 	Test accuracy: 0.967
# 	Confusion matrix:
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]
# 	Class versicolor confused with class virginica: 1 times
# Decision tree with criterion='gini', max_depth=3, split 3:
# 	Test accuracy: 0.967
# 	Confusion matrix:
# [[14  0  0]
#  [ 0  7  1]
#  [ 0  0  8]]
# 	Class versicolor confused with class virginica: 1 times
# Decision tree with criterion='gini', max_depth=3, split 4:
# 	Test accuracy: 0.967
# 	Confusion matrix:
# [[10  0  0]
#  [ 0 10  0]
#  [ 0  1  9]]
# 	Class virginica confused with class versicolor: 1 times
# Decision tree with criterion='gini', max_depth=3, split 5:
# 	Test accuracy: 0.967
# 	Confusion matrix:
# [[16  0  0]
#  [ 0  4  1]
#  [ 0  0  9]]
# ...

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split

# Load the iris dataset
iris = load_iris()

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3, random_state=1)

# Train a decision tree classifier with entropy as the impurity measure and a maximum depth of 3
clf = DecisionTreeClassifier(criterion='entropy', max_depth=3).fit(X_train, y_train)

# Plot the decision tree
plot_tree(clf)

# Identify the misclassified samples
misclassified_indexes = [i for i in range(len(y_test)) if y_test[i] != clf.predict(X_test)[i]]

# Print the misclassified samples and their corresponding true and predicted labels
print("Misclassified samples:")
for i in misclassified_indexes:
    print(f"\tSample {i}: true label={y_test[i]}, predicted label={clf.predict(X_test[i].reshape(1, -1))[0]}")

# Identify the corresponding leaf nodes and their path of decisions
print("Decision paths for misclassified samples:")
# Out:
# Misclassified samples:
# 	Sample 22: true label=1, predicted label=2
# 	Sample 42: true label=2, predicted label=1
# Decision paths for misclassified samples:
